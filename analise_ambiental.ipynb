# %% [markdown]
# <a href="https://colab.research.google.com/github/EricaRaujoData/EricaRaujoData/blob/master/analise_ambiental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importação do pacote pandas para tratamento e análise de dados
import pandas as pd

# %%
#lendo o arquivo de banco de dados
df = pd.read_excel("/content/drive/MyDrive/Bases de Dados/(2) atlas_ambiental.xlsx")

# %%
#visualizando as 5 primeiras linhas
df.head()
# Out:
#    cód_ibge          distritos  renda  quota  escolaridade  idade  \
# 0         1          Água Rasa   1961  34.62           7.6     32
# 1         2  Alto de Pinheiros   4180  75.96           8.4     33
# 2         3         Anhanguera   1093   4.50           5.8     23
# 3         4         Aricanduva   1311  21.02           6.8     27
# 4         5        Artur Alvim   1248  15.91           7.0     27
#
#    mortalidade    txcresc  causasext  favel  denspop
# 0        13.86  -1.840000      52.98   0.00   125.61
# 1         8.68  -2.520000      38.57   0.69    57.56
# 2        15.36  18.120001      22.68   0.00     8.57
# 3        18.43  -1.070000      76.22   5.38   138.54
# 4        19.73  -1.400000      67.25   4.11   167.40

# %%
#trocando o nome dos títulos das colunas e atribuindo ao novo data frame (df)
df = df.rename(columns={"cód_ibge":"IBGE"})

# %%
df.head()
# Out:
#    IBGE          distritos  renda  quota  escolaridade  idade  mortalidade  \
# 0     1          Água Rasa   1961  34.62           7.6     32        13.86
# 1     2  Alto de Pinheiros   4180  75.96           8.4     33         8.68
# 2     3         Anhanguera   1093   4.50           5.8     23        15.36
# 3     4         Aricanduva   1311  21.02           6.8     27        18.43
# 4     5        Artur Alvim   1248  15.91           7.0     27        19.73
#
#      txcresc  causasext  favel  denspop
# 0  -1.840000      52.98   0.00   125.61
# 1  -2.520000      38.57   0.69    57.56
# 2  18.120001      22.68   0.00     8.57
# 3  -1.070000      76.22   5.38   138.54
# 4  -1.400000      67.25   4.11   167.40

# %%
#total de linhas e colunas BD
df.shape
# Out:
# (96, 11)

# %%
#apresentando os tipos das métricas
df.dtypes
# Out:
# IBGE              int64
# distritos        object
# renda             int64
# quota           float64
# escolaridade    float64
# idade             int64
# mortalidade     float64
# txcresc         float64
# causasext       float64
# favel           float64
# denspop         float64
# dtype: object

# %%
#retornar as últimas linhas do dataframe
df.tail()
# Out:
#     IBGE      distritos  renda  quota  escolaridade  idade  mortalidade  \
# 91    92  Vila Medeiros   1405  19.76           6.8     27        15.43
# 92    93  Vila Prudente   1755  32.08           7.2     30        14.36
# 93    94     Vila Sônia   2970  41.41           7.4     27        16.76
# 94    95   São Domingos   2047  23.51           6.8     26        14.30
# 95    96        Lajeado    775   8.49           5.4     21        18.65
#
#     txcresc  causasext  favel  denspop
# 91    -1.41      77.98   2.49   188.93
# 92    -2.55      66.51   7.43   101.44
# 93    -0.90      74.68  14.93    80.12
# 94     0.71      62.35   8.55    72.92
# 95     2.83     103.32   3.84   141.01

# %%
#gerar estatísticas descritivas do banco de dados
df.describe()
# Out:
#             IBGE        renda       quota  escolaridade      idade  \
# count  96.000000    96.000000   96.000000     96.000000  96.000000
# mean   48.500000  1856.218750   30.478021      7.075000  27.395833
# std    27.856777   970.774441   23.040243      1.008908   4.385332
# min     1.000000   159.000000    0.610000      4.800000  20.000000
# 25%    24.750000  1150.000000   12.400000      6.300000  23.000000
# 50%    48.500000  1628.000000   24.305000      7.000000  27.000000
# 75%    72.250000  2315.500000   40.990000      7.850000  31.000000
# max    96.000000  5146.000000  104.730000      9.200000  36.000000
#
#        mortalidade    txcresc   causasext      favel     denspop
# count    96.000000  96.000000   96.000000  96.000000   96.000000
# mean     15.992812   0.041146   71.086667   5.932188   99.860104
# std       4.994409   3.509652   23.315169   7.883763   49.606814
# min       6.460000  -6.240000   22.680000   0.000000    0.370000
# ...

# %%
#contar quantas linhas ou quantos casos e quantas colunas o banco de dados tem
df.shape
# Out:
# (96, 11)

# %%
#apresentar o nome das colunas e/ou métricas
df.columns
# Out:
# Index(['IBGE', 'distritos', 'renda', 'quota', 'escolaridade', 'idade',
#        'mortalidade', 'txcresc', 'causasext', 'favel', 'denspop'],
#       dtype='object')

# %%
#analisar registros únicos de idade
df["idade"].unique()
# Out:
# array([32, 33, 23, 27, 31, 30, 22, 29, 24, 26, 21, 35, 34, 36, 28, 20, 25])

# %%
#selecionar apenas os casos do distrito de Aricanduva
Aricanduva = df.loc[df["distritos"] == "Aricanduva"]
# Out:
#    IBGE   distritos  renda  quota  escolaridade  idade  mortalidade  txcresc  \
# 3     4  Aricanduva   1311  21.02           6.8     27        18.43    -1.07
#
#    causasext  favel  denspop
# 3      76.22   5.38   138.54

# %%
#retorna uma lista de valores únicos de "Aricanduva" encontrados na coluna
#"distritos" do DataFrame
# Out:
# array(['Aricanduva'], dtype=object)

# %%
#agrupamento de dados - quantos distritos tem pessoas com cada idade?
df.groupby("idade")["distritos"].nunique()
# Out:
# idade
# 20     1
# 21     9
# 22     3
# 23    12
# 24     9
# 25     2
# 26     8
# 27     7
# 28     3
# 29     7
# 30     7
# 31     7
# 32     7
# 33     3
# 34     7
# 35     3
# 36     1
# Name: distritos, dtype: int64

# %%
#calcular a média dos valores da coluna mortalidade
df.groupby("distritos")["mortalidade"].mean()
# Out:
# distritos
# Alto de Pinheiros     8.68
# Anhanguera           15.36
# Aricanduva           18.43
# Artur Alvim          19.73
# Barra Funda           8.62
#                      ...
# Vila Matilde         19.13
# Vila Medeiros        15.43
# Vila Prudente        14.36
# Vila Sônia           16.76
# Água Rasa            13.86
# Name: mortalidade, Length: 96, dtype: float64
